# %%
# !/opt/conda/envs/mxnet1/bin/python3 train.py --step=10500 --gpu 3 --outdir=model-10500 --predict
# !/opt/conda/envs/mxnet1/bin/python3 train.py --step=27500 --gpu 3 --outdir=model-27500 --predict
# !/opt/conda/envs/mxnet1/bin/python3 train.py --step=28500 --gpu 3 --outdir=model-28500 --predict
# !/opt/conda/envs/mxnet1/bin/python3 train.py --step=29500 --gpu 3 --outdir=model-29500 --predict
# !/opt/conda/envs/mxnet1/bin/python3 train.py --step=30500 --gpu 3 --outdir=model-30500 --predict
# Out:
# /opt/conda/envs/mxnet1/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /opt/conda/envs/mxnet1/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /opt/conda/envs/mxnet1/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
# !/opt/conda/envs/mxnet1/bin/python3 train.py --step=26000 --gpu 3 --outdir=model-26000 --predict
# Out:
# /opt/conda/envs/mxnet1/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /opt/conda/envs/mxnet1/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /opt/conda/envs/mxnet1/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...
